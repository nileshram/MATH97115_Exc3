# %% [markdown]
# ### Configure Paths

# %%
import os
os.chdir("/home/nilesh/PycharmProjects/MATH97115 - SPXMODEL/src")
os.getcwd()
# Out:
# '/home/nilesh/PycharmProjects/MATH97115 - SPXMODEL/src'

# %% [markdown]
# ### Import Modules

# %%
from computation.stats import StatsEngine
from graph.lib import Scatter, Histogram

# %%
# %%capture #hides data output

#create engine
stats = StatsEngine()

#run the engine
stats.generate_samples()
stats.generate_ecdf()

# %% [markdown]
# ### Plot ECDF for exp. random samples

# %%
Scatter(stats)

# %%
### Plot Density for exp. random samples

# %%
Histogram(stats)
